# %% [markdown]
# # 🌍 **Global Life Expectancy Analysis**

# %% [markdown]
# ## 🎯 Aim
#
# To analyze global life expectancy data using Python in order to identify major health and demographic factors affecting lifespan through data preprocessing, exploratory data analysis, and visualization techniques.

# %% [markdown]
# **OBJECTIVES:**
#
# To clean and preprocess the dataset.
#
# To identify and handle missing values.
#
# To perform exploratory data analysis.
#
# To visualize life expectancy trends across countries and genders.
#
# To detect outliers and inconsistencies in the data.
#
# To generate meaningful insights using Python.

# %% [markdown]
# **INTRODUCTION:**
#
# Life expectancy is one of the most important indicators of a country’s overall health and development. By analyzing life expectancy data, meaningful insights can be obtained regarding healthcare quality, socio-economic conditions, and population wellbeing.

# %% [markdown]
# **DESCRIPTION**
#
# The dataset contains global life expectancy records collected from the World Health Organization. It includes country-wise and gender-wise life expectancy values across multiple years.

# %% [markdown]
# # 📊**Column Descriptions**
#  Column Name              | Meaning                                                                                |
# | ------------------------ | -------------------------------------------------------------------------------------- |
# | `IND_ID`                 | Unique identifier for the health indicator record.                                     |
# | `IND_CODE`               | Indicator code assigned by the World Health Organization for a specific health metric. |
# | `IND_UUID`               | Unique universal identifier for the indicator dataset.                                 |
# | `IND_PER_CODE`           | Indicator periodicity/code related to the measurement category.                        |
# | `DIM_TIME`               | Year of the recorded data (e.g., 2000, 2001, etc.).                                    |
# | `DIM_TIME_TYPE`          | Type of time measurement. In your dataset it is mostly `YEAR`.                         |
# | `DIM_GEO_CODE_M49`       | Geographic country code based on the UN M49 standard.                                  |
# | `DIM_GEO_CODE_TYPE`      | Type of geographic region (e.g., COUNTRY).                                             |
# | `DIM_PUBLISH_STATE_CODE` | Publication status of the data (e.g., PUBLISHED).                                      |
# | `IND_NAME`               | Name of the indicator being measured. Example: *Life expectancy (at birth)*.           |
# | `GEO_NAME_SHORT`         | Short name of the country or geographic region.                                        |
# | `DIM_SEX`                | Gender category for the data (`MALE`, `FEMALE`, or `BOTH`).                            |
# | `AMOUNT_N`               | Main numerical value of life expectancy. This is the actual life expectancy value.     |
# | `AMOUNT_NL`              | Lower confidence interval / lower estimated bound of the life expectancy value.        |
# | `AMOUNT_NU`              | Upper confidence interval / upper estimated bound of the life expectancy value.        |

# %% [markdown]
# #📚 **Import Python Libraries**

# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  📊**Load Dataset**

# %%
# Load the life expectancy dataset

df = pd.read_csv("/content/Global Life Expectancy Analysis.csv")

df.head()
# Out:
#                  IND_ID       IND_CODE IND_UUID   IND_PER_CODE  DIM_TIME  \
# 0  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 1  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 2  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 3  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 4  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
#
#   DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE DIM_PUBLISH_STATE_CODE  \
# 0          YEAR               688           COUNTRY              PUBLISHED
# 1          YEAR               690           COUNTRY              PUBLISHED
# 2          YEAR               694           COUNTRY              PUBLISHED
# 3          YEAR               702           COUNTRY              PUBLISHED
# 4          YEAR               703           COUNTRY              PUBLISHED
#
#                      IND_NAME GEO_NAME_SHORT DIM_SEX   AMOUNT_N  AMOUNT_NL  \
# 0  Life expectancy (at birth)         Serbia  FEMALE  74.334559  74.254810
# 1  Life expectancy (at birth)     Seychelles  FEMALE  76.455919  76.227948
# 2  Life expectancy (at birth)   Sierra Leone  FEMALE  51.577824  50.603903
# 3  Life expectancy (at birth)      Singapore  FEMALE  80.774170  80.751426
# 4  Life expectancy (at birth)       Slovakia  FEMALE  77.405510  77.356596
#
#    AMOUNT_NU
# 0  74.526428
# 1  76.712025
# 2  52.778978
# 3  80.876353
# 4  77.519091

# %% [markdown]
# # 🔍**Understand the Dataset**
#
# Dataset understanding is the initial step in data analysis where we explore the dataset's columns, data types, number of records, and overall structure to gain familiarity with the data.

# %% [markdown]
# 1. Check shape

# %%
df.shape
# Out:
# (12936, 15)

# %% [markdown]
# 2. Check column names

# %%
df.columns
# Out:
# Index(['IND_ID', 'IND_CODE', 'IND_UUID', 'IND_PER_CODE', 'DIM_TIME',
#        'DIM_TIME_TYPE', 'DIM_GEO_CODE_M49', 'DIM_GEO_CODE_TYPE',
#        'DIM_PUBLISH_STATE_CODE', 'IND_NAME', 'GEO_NAME_SHORT', 'DIM_SEX',
#        'AMOUNT_N', 'AMOUNT_NL', 'AMOUNT_NU'],
#       dtype='object')

# %% [markdown]
# 3. Check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12936 entries, 0 to 12935
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IND_ID                  12936 non-null  object
#  1   IND_CODE                12936 non-null  object
#  2   IND_UUID                12936 non-null  object
#  3   IND_PER_CODE            12936 non-null  object
#  4   DIM_TIME                12936 non-null  int64
#  5   DIM_TIME_TYPE           12936 non-null  object
#  6   DIM_GEO_CODE_M49        12936 non-null  int64
#  7   DIM_GEO_CODE_TYPE       12936 non-null  object
#  8   DIM_PUBLISH_STATE_CODE  12936 non-null  object
#  9   IND_NAME                12936 non-null  object
#  10  GEO_NAME_SHORT          12936 non-null  object
#  11  DIM_SEX                 12936 non-null  object
#  12  AMOUNT_N                12936 non-null  float64
#  13  AMOUNT_NL               12916 non-null  float64
#  14  AMOUNT_NU               12916 non-null  float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.5+ MB

# %% [markdown]
# # 🧹**Data Cleaning & Pre-processing**
#
# Data cleaning and pre-processing is the process of improving data quality by handling missing values, removing duplicates, correcting inconsistencies, and transforming data into a suitable format for analysis.

# %% [markdown]
# 1. Check null values

# %%
df.isnull().sum()
# Out:
# IND_ID                     0
# IND_CODE                   0
# IND_UUID                   0
# IND_PER_CODE               0
# DIM_TIME                   0
# DIM_TIME_TYPE              0
# DIM_GEO_CODE_M49           0
# DIM_GEO_CODE_TYPE          0
# DIM_PUBLISH_STATE_CODE     0
# IND_NAME                   0
# GEO_NAME_SHORT             0
# DIM_SEX                    0
# AMOUNT_N                   0
# AMOUNT_NL                 20
# AMOUNT_NU                 20
# dtype: int64

# %% [markdown]
# 2. Fill Missing Values Using Mean:
#
# Missing values in the confidence interval columns were identified and replaced using mean imputation to maintain dataset consistency.

# %%
df['AMOUNT_NL'] = df['AMOUNT_NL'].fillna(df['AMOUNT_NL'].mean())

df['AMOUNT_NU'] = df['AMOUNT_NU'].fillna(df['AMOUNT_NU'].mean())

# %% [markdown]
# 3. Verify Missing Values Removed

# %%
df.isnull().sum()
# Out:
# IND_ID                    0
# IND_CODE                  0
# IND_UUID                  0
# IND_PER_CODE              0
# DIM_TIME                  0
# DIM_TIME_TYPE             0
# DIM_GEO_CODE_M49          0
# DIM_GEO_CODE_TYPE         0
# DIM_PUBLISH_STATE_CODE    0
# IND_NAME                  0
# GEO_NAME_SHORT            0
# DIM_SEX                   0
# AMOUNT_N                  0
# AMOUNT_NL                 0
# AMOUNT_NU                 0
# dtype: int64

# %% [markdown]
# 4. Handling Duplicate Values:
#
# Check Duplicate Rows- Duplicate rows were checked and removed to avoid redundancy and ensure data accuracy.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **📝Formatting & Data Type Corrections**
#
# Data formatting techniques such as string cleaning, whitespace removal, and datatype conversion were applied for consistency.

# %% [markdown]
# 1. Check Data Types

# %%
df.dtypes
# Out:
# IND_ID                     object
# IND_CODE                   object
# IND_UUID                   object
# IND_PER_CODE               object
# DIM_TIME                    int64
# DIM_TIME_TYPE              object
# DIM_GEO_CODE_M49            int64
# DIM_GEO_CODE_TYPE          object
# DIM_PUBLISH_STATE_CODE     object
# IND_NAME                   object
# GEO_NAME_SHORT             object
# DIM_SEX                    object
# AMOUNT_N                  float64
# AMOUNT_NL                 float64
# AMOUNT_NU                 float64
# dtype: object

# %% [markdown]
# 2. Convert Country Names to Proper Format

# %%
df['GEO_NAME_SHORT'] = df['GEO_NAME_SHORT'].str.title()

# %% [markdown]
# 3. Remove Extra Spaces

# %%
df['GEO_NAME_SHORT'] = df['GEO_NAME_SHORT'].str.strip()

# %% [markdown]
# # **⚙️Feature Engineering / Derived Features**
#
# Feature engineering is the process of creating new variables (features) from existing data to improve analysis and extract more meaningful information.
#
# Create Life Expectancy Category:

# %%
def category(x):
    if x < 60:
        return 'Low'
    elif x < 75:
        return 'Medium'
    else:
        return 'High'

df['LIFE_EXPECTANCY_CATEGORY'] = df['AMOUNT_N'].apply(category)

# %% [markdown]
# Feature engineering was performed by creating a new categorical feature called LIFE_EXPECTANCY_CATEGORY from the existing numerical life expectancy column (AMOUNT_N).
# The life expectancy values were grouped into three categories:
#
# Low : Life Expectancy less than 60 years
#
# Medium : Life Expectancy between 60 and 75 years
#
# High : Life Expectancy greater than or equal to 75 years
#
# This derived feature simplifies the interpretation of life expectancy data and enables easier comparison of countries based on their overall life expectancy levels.

# %% [markdown]
# # **🔄Data Transformation**
#
# Data transformation was performed using Min-Max Normalization on the AMOUNT_N (Life Expectancy) column. The purpose of normalization is to scale numerical values to a common range between 0 and 1 while preserving the relative differences between observations.

# %%
df['AMOUNT_N_Normalized'] = (
    (df['AMOUNT_N'] - df['AMOUNT_N'].min()) /
    (df['AMOUNT_N'].max() - df['AMOUNT_N'].min()))

# %% [markdown]
# After normalization, all life expectancy values were transformed into a range between 0 and 1, making the dataset more consistent and suitable for analysis.

# %% [markdown]
# # **🚨Outlier Detection**
#
# Outliers are data points that differ significantly from the majority of observations in a dataset. They may indicate unusual conditions, measurement errors, or rare events.

# %% [markdown]
# **Calculate IQR and Detect Outliers**

# %%
Q1 = df['AMOUNT_N'].quantile(0.25)
Q3 = df['AMOUNT_N'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

outliers = df[(df['AMOUNT_N'] < lower_bound) | (df['AMOUNT_N'] > upper_bound)]

print("Number of Outliers:", len(outliers))
# Out:
# Q1: 64.30417653999999
# Q3: 77.0067675875
# IQR: 12.702591047500007
# Lower Bound: 45.250289968749975
# Upper Bound: 96.06065415875
# Number of Outliers: 77

# %% [markdown]
# Outliers were identified using both the Interquartile Range (IQR) method and boxplot visualization.
#
# The IQR was calculated as:
#
# IQR=Q3−Q1
#
# where:
#
# Q1 = 25th percentile
# Q3 = 75th percentile
#
# The lower and upper bounds were determined using:
#
# Lower Bound=Q1−1.5×IQR
# Upper Bound=Q3+1.5×IQR
#
# Any life expectancy value outside these bounds was considered an outlier.

# %% [markdown]
# **View the Outlier Records**

# %%
outliers[['GEO_NAME_SHORT', 'DIM_TIME', 'DIM_SEX', 'AMOUNT_N']].head(10)
# Out:
#      GEO_NAME_SHORT  DIM_TIME DIM_SEX   AMOUNT_N
# 285         Lesotho      2005  FEMALE  44.041179
# 476         Lesotho      2006  FEMALE  43.538907
# 575        Eswatini      2002  FEMALE  45.072766
# 771        Eswatini      2003  FEMALE  43.832245
# 964        Eswatini      2004  FEMALE  42.946079
# 1175         Zambia      2000  FEMALE  45.138348
# 1307       Eswatini      2005  FEMALE  42.739857
# 1327       Eswatini      2006  FEMALE  43.784754
# 1407          Haiti      2010  FEMALE  36.599153
# 1556       Eswatini      2007  FEMALE  45.083373

# %% [markdown]
# **Outlier Analysis Using Boxplot**
#
# A boxplot was created to compare life expectancy across different gender categories (Male, Female, and Both).
#
# The plot helps visualize the spread of data, median values, and potential outliers within each group.

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x='DIM_SEX', y='AMOUNT_N', data=df)

plt.title('Life Expectancy by Gender')
plt.xlabel('Gender')
plt.ylabel('Life Expectancy (Years)')

plt.show()

# %% [markdown]
# **Explanation:**
#
# The individual points appearing outside the whiskers of the boxplot represent outliers, which are life expectancy values significantly lower or higher than the majority of observations for that gender category.
#
# In this dataset, most outliers correspond to countries experiencing unusually low life expectancy due to factors such as poor healthcare access, disease burden, economic challenges, or social instability.
#
# These outliers were retained in the analysis because they represent actual country-level observations rather than data entry errors and provide valuable insights into global health disparities.

# %% [markdown]
# # 📁**Final Cleaned Dataset Check**
#
# The purpose is to verify that all preprocessing steps were successfully completed and that the dataset is ready for analysis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12936 entries, 0 to 12935
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   IND_ID                    12936 non-null  object
#  1   IND_CODE                  12936 non-null  object
#  2   IND_UUID                  12936 non-null  object
#  3   IND_PER_CODE              12936 non-null  object
#  4   DIM_TIME                  12936 non-null  int64
#  5   DIM_TIME_TYPE             12936 non-null  object
#  6   DIM_GEO_CODE_M49          12936 non-null  int64
#  7   DIM_GEO_CODE_TYPE         12936 non-null  object
#  8   DIM_PUBLISH_STATE_CODE    12936 non-null  object
#  9   IND_NAME                  12936 non-null  object
#  10  GEO_NAME_SHORT            12936 non-null  object
#  11  DIM_SEX                   12936 non-null  object
#  12  AMOUNT_N                  12936 non-null  float64
#  13  AMOUNT_NL                 12936 non-null  float64
#  14  AMOUNT_NU                 12936 non-null  float64
#  15  LIFE_EXPECTANCY_CATEGORY  12936 non-null  object
#  16  AMOUNT_N_Normalized       12936 non-null  float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 1.7+ MB

# %%
df.head()
# Out:
#                  IND_ID       IND_CODE IND_UUID   IND_PER_CODE  DIM_TIME  \
# 0  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 1  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 2  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 3  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 4  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
#
#   DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE DIM_PUBLISH_STATE_CODE  \
# 0          YEAR               688           COUNTRY              PUBLISHED
# 1          YEAR               690           COUNTRY              PUBLISHED
# 2          YEAR               694           COUNTRY              PUBLISHED
# 3          YEAR               702           COUNTRY              PUBLISHED
# 4          YEAR               703           COUNTRY              PUBLISHED
#
#                      IND_NAME GEO_NAME_SHORT DIM_SEX   AMOUNT_N  AMOUNT_NL  \
# 0  Life expectancy (at birth)         Serbia  FEMALE  74.334559  74.254810
# 1  Life expectancy (at birth)     Seychelles  FEMALE  76.455919  76.227948
# 2  Life expectancy (at birth)   Sierra Leone  FEMALE  51.577824  50.603903
# 3  Life expectancy (at birth)      Singapore  FEMALE  80.774170  80.751426
# 4  Life expectancy (at birth)       Slovakia  FEMALE  77.405510  77.356596
#
#    AMOUNT_NU LIFE_EXPECTANCY_CATEGORY  AMOUNT_N_Normalized
# 0  74.526428                   Medium             0.743234
# 1  76.712025                     High             0.785017
# 2  52.778978                      Low             0.295019
# 3  80.876353                     High             0.870069
# 4  77.519091                     High             0.803720

# %% [markdown]
# After completing the data cleaning and preprocessing steps, a final inspection of the dataset was performed using df.info() and df.head().
#
# 1. df.info() was used to verify the data types of all columns, confirm that
# missing values had been handled, and ensure the dataset structure was correct.
# 2. df.head() was used to preview the first few records and validate that the cleaned and transformed data appeared as expected.

# %% [markdown]
# # **📈EDA (Exploratory Data Analysis)**
#
# EDA is the process of exploring and understanding your data before drawing conclusions or building models.
#
# EDA includes both visual and non-visual analysis. Non-visual EDA involves examining dataset structure, data types, descriptive statistics, missing values, duplicates, unique values, correlations, and group-wise summaries. Visualization is used later to communicate these findings more effectively.

# %% [markdown]
# **NON-VISUAL EDA**

# %% [markdown]
# Question. 1
#
# What are the key statistics of numerical variables?

# %%
df.describe()
# Out:
#            DIM_TIME  DIM_GEO_CODE_M49      AMOUNT_N     AMOUNT_NL  \
# count  12936.000000      12936.000000  12936.000000  12936.000000
# mean    2010.500000        453.709184     70.170890     69.705097
# std        6.344534        273.233973      8.799313      9.087506
# min     2000.000000          1.000000     36.599153     36.002764
# 25%     2005.000000        217.000000     64.304177     63.583745
# 50%     2010.500000        437.000000     71.736775     71.347639
# 75%     2016.000000        691.000000     77.006768     76.778246
# max     2021.000000        958.000000     87.371027     87.320650
#
#           AMOUNT_NU  AMOUNT_N_Normalized
# count  12936.000000         12936.000000
# mean      70.675974             0.661227
# std        8.485131             0.173311
# min       37.362718             0.000000
# 25%       65.102239             0.545677
# 50%       72.161169             0.692069
# 75%       77.256349             0.795866
# max       87.421403             1.000000

# %% [markdown]
# **Insight**
#
# Provides count, mean, standard deviation, minimum, quartiles, and maximum values. Gives an overall understanding of the distribution of life expectancy.

# %% [markdown]
# Question. 2
#
# How many unique countries are present?

# %%
df['GEO_NAME_SHORT'].nunique()
# Out:
# 196

# %% [markdown]
# **Insight**
#
# Returns the number of unique countries. Shows the geographical coverage of the dataset.

# %% [markdown]
# Question. 3
#
# How are observations distributed among Low, Medium, and High categories?

# %%
df['LIFE_EXPECTANCY_CATEGORY'].value_counts()
# Out:
# LIFE_EXPECTANCY_CATEGORY
# Medium    6528
# High      4523
# Low       1885
# Name: count, dtype: int64

# %% [markdown]
# **Insight**
#
# Displays category frequencies. Identifies the dominant life expectancy group.

# %% [markdown]
# Question. 4
#
# Which country has the highest average life expectancy?

# %%
df.groupby('GEO_NAME_SHORT')['AMOUNT_N'].mean().sort_values(ascending=False).head(10)
# Out:
# GEO_NAME_SHORT
# Japan          83.162066
# Switzerland    81.926416
# Australia      81.735940
# Singapore      81.672171
# Iceland        81.518940
# Italy          81.442308
# Spain          81.342748
# Sweden         81.195067
# France         80.994688
# Luxembourg     80.979243
# Name: AMOUNT_N, dtype: float64

# %% [markdown]
# **Insight**
#
# Lists the top 10 countries. Highlights countries with the best life expectancy outcomes.

# %% [markdown]
# Question. 5
#
# Which countries have the lowest average life expectancy?

# %%
df.groupby('GEO_NAME_SHORT')['AMOUNT_N'].mean().sort_values().head(10)
# Out:
# GEO_NAME_SHORT
# Lesotho                     48.094219
# Eswatini                    48.353560
# Central African Republic    48.887849
# Somalia                     51.305413
# Zimbabwe                    52.071631
# Mozambique                  54.235879
# Guinea-Bissau               55.115300
# Sierra Leone                55.315597
# Zambia                      55.438374
# Chad                        55.607305
# Name: AMOUNT_N, dtype: float64

# %% [markdown]
# **Insight**
#
# Lists the bottom 10 countries. Highlights countries facing major health challenges.

# %% [markdown]
# Question. 6
#
# Does life expectancy vary by gender?

# %%
df.groupby('DIM_SEX')['AMOUNT_N'].mean()
# Out:
# DIM_SEX
# FEMALE    72.600338
# MALE      67.764630
# TOTAL     70.147702
# Name: AMOUNT_N, dtype: float64

# %% [markdown]
# **Insight**
#
# Shows average life expectancy for each gender. Females generally have higher life expectancy than males.

# %% [markdown]
# Question. 7
#
# How has average life expectancy changed over time?

# %%
df.groupby('DIM_TIME')['AMOUNT_N'].mean()
# Out:
# DIM_TIME
# 2000    66.982075
# 2001    67.309410
# 2002    67.542211
# 2003    67.816733
# 2004    68.152393
# 2005    68.510542
# 2006    68.956156
# 2007    69.326213
# 2008    69.664641
# 2009    70.061264
# 2010    70.328478
# 2011    70.738773
# 2012    71.055922
# 2013    71.370380
# 2014    71.532083
# 2015    71.718778
# 2016    71.980832
# 2017    72.204529
# 2018    72.448233
# 2019    72.650740
# 2020    72.095015
# 2021    71.314180
# Name: AMOUNT_N, dtype: float64

# %% [markdown]
# **Insight**
#
# Provides yearly averages. Reveals whether life expectancy is improving over time.

# %% [markdown]
# Question. 8
#
# What relationships exist among numerical variables?

# %%
df[['AMOUNT_N',
    'AMOUNT_NL',
    'AMOUNT_NU',
    'AMOUNT_N_Normalized']].corr()
# Out:
#                      AMOUNT_N  AMOUNT_NL  AMOUNT_NU  AMOUNT_N_Normalized
# AMOUNT_N             1.000000   0.998270   0.998165             1.000000
# AMOUNT_NL            0.998270   1.000000   0.998519             0.998270
# AMOUNT_NU            0.998165   0.998519   1.000000             0.998165
# AMOUNT_N_Normalized  1.000000   0.998270   0.998165             1.000000

# %% [markdown]
# **Insight**
#
# Displays the correlation matrix. Identifies strong positive or negative relationships.

# %% [markdown]
# Question. 9
#
# How does average life expectancy differ across categories?

# %%
df.groupby('LIFE_EXPECTANCY_CATEGORY')['AMOUNT_N'].mean()
# Out:
# LIFE_EXPECTANCY_CATEGORY
# High      78.942438
# Low       54.662720
# Medium    68.571501
# Name: AMOUNT_N, dtype: float64

# %% [markdown]
# **Insight**
#
# Shows average life expectancy for Low, Medium, and High groups. Validates the effectiveness of the derived feature.

# %% [markdown]
# # 📈**Structure of EDA with Visualisations**

# %% [markdown]
# # 1️⃣ **UNIVARIATE ANALYSIS**

# %% [markdown]
# Analysis of one variable at a time.
#
# Purpose:
#
# -Understand distribution
#
# -Identify outliers
#
# -Check frequency and spread

# %% [markdown]
# Question. 1
#
# What is the distribution of life expectancy values?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['AMOUNT_N'], bins=20)

plt.title('Distribution of Life Expectancy')
plt.xlabel('Life Expectancy (Years)')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# **Insight**
#
# Most life expectancy values are concentrated between 60 and 80 years. The majority of countries have moderate to high life expectancy.

# %% [markdown]
# Question. 2
#
# What is the density distribution of life expectancy?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.kdeplot(df['AMOUNT_N'], fill=True)

plt.title('Density Distribution of Life Expectancy')
plt.xlabel('Life Expectancy (Years)')

plt.show()

# %% [markdown]
# **Insight**
#
# The density curve shows where life expectancy values are most concentrated. Helps identify the most common life expectancy range globally.

# %% [markdown]
# Question. 3
#
# Are there any outliers in life expectancy?

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df['AMOUNT_N'])

plt.title('Boxplot of Life Expectancy')
plt.xlabel('Life Expectancy (Years)')

plt.show()

# %% [markdown]
# **Insight**
#
# Several observations appear outside the whiskers and are considered outliers. These outliers represent countries with unusually low life expectancy values.

# %% [markdown]
# Question. 4
#
# How are records distributed across genders?

# %%
plt.figure(figsize=(6,5))

sns.countplot(x='DIM_SEX', data=df)

plt.title('Distribution of Records by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# **Insight**
#
# Records are distributed among Male, Female, and Both categories.
# The dataset supports gender-wise comparisons.

# %% [markdown]
# Question. 5
#
# How are observations distributed across life expectancy categories?

# %%
plt.figure(figsize=(6,5))

sns.countplot(x='LIFE_EXPECTANCY_CATEGORY', data=df)

plt.title('Distribution of Life Expectancy Categories')
plt.xlabel('Category')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# **Insight**
#
# Most observations belong to Medium and High categories. Many countries have achieved relatively high life expectancy levels.

# %% [markdown]
# # **2️⃣**. **BIVARIATE ANALYSIS**

# %% [markdown]
# Analysis of two variables together.
#
# Purpose:
#
# -Compare groups
#
# -Identify trends and relationships

# %% [markdown]
# Question. 6
#
# Does life expectancy vary by gender?

# %%
plt.figure(figsize=(6,5))

sns.boxplot(
    x='DIM_SEX',
    y='AMOUNT_N',
    data=df
)

plt.title('Life Expectancy by Gender')
plt.xlabel('Gender')
plt.ylabel('Life Expectancy (Years)')

plt.show()

# %% [markdown]
# **Insight**
#
# Female life expectancy is generally higher than male life expectancy. Women tend to live longer than men globally.

# %% [markdown]
# Question. 7
#
# What is the average life expectancy for each gender?

# %%
gender_avg = df.groupby('DIM_SEX')['AMOUNT_N'].mean()

plt.figure(figsize=(6,5))

gender_avg.plot(kind='bar')

plt.title('Average Life Expectancy by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Life Expectancy')

plt.show()

# %% [markdown]
# **Insight**
#
# Female life expectancy has a higher average value. A gender gap exists in life expectancy outcomes.

# %% [markdown]
# Question. 8
#
# How has life expectancy changed over time?

# %%
yearly_avg = df.groupby('DIM_TIME')['AMOUNT_N'].mean()

plt.figure(figsize=(10,5))

plt.plot(
    yearly_avg.index,
    yearly_avg.values,
    marker='o'
)

plt.title('Average Life Expectancy Over Time')
plt.xlabel('Year')
plt.ylabel('Average Life Expectancy')

plt.show()

# %% [markdown]
# **Insight**
#
# Life expectancy generally increases over time. Healthcare and living conditions have improved globally.

# %% [markdown]
# Question. 9
#
# Which countries have the highest life expectancy?

# %%
top10 = (
    df.groupby('GEO_NAME_SHORT')['AMOUNT_N']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(10,5))

top10.plot(kind='bar')

plt.title('Top 10 Countries by Life Expectancy')
plt.xlabel('Country')
plt.ylabel('Average Life Expectancy')

plt.show()

# %% [markdown]
# **Insight**
#
# The chart shows the countries with the highest life expectancy. These countries likely have strong healthcare systems and better living standards.

# %% [markdown]
# Question. 10
#
# Which countries have the lowest life expectancy?

# %%
bottom10 = (
    df.groupby('GEO_NAME_SHORT')['AMOUNT_N']
    .mean()
    .sort_values()
    .head(10)
)

plt.figure(figsize=(10,5))

bottom10.plot(kind='bar')

plt.title('Bottom 10 Countries by Life Expectancy')
plt.xlabel('Country')
plt.ylabel('Average Life Expectancy')

plt.show()

# %% [markdown]
# **Insight**
#
# The chart identifies countries with the lowest life expectancy. These countries may face healthcare, economic, or social challenges.

# %% [markdown]
# Question. 11
#
# What is the relationship between lower and upper confidence limits?

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='AMOUNT_NL',
    y='AMOUNT_NU',
    data=df
)

plt.title('Lower vs Upper Confidence Limits')
plt.xlabel('AMOUNT_NL')
plt.ylabel('AMOUNT_NU')

plt.show()

# %% [markdown]
# **Insight**
#
# A strong positive relationship exists. Higher lower-bound estimates are associated with higher upper-bound estimates.

# %% [markdown]
# # **3️⃣**. **MULTIVARIATE ANALYSIS**

# %% [markdown]
# Analysis of three or more variables simultaneously.
#
# Purpose:
#
# -Discover complex patterns
#
# -Understand interactions between multiple variables

# %% [markdown]
# Queation. 12
#
# How does life expectancy vary across genders over time?

# %%
gender_year = df.groupby(['DIM_TIME','DIM_SEX'])['AMOUNT_N'].mean().reset_index()

sns.lineplot(
    data=gender_year,
    x='DIM_TIME',
    y='AMOUNT_N',
    hue='DIM_SEX'
)
# Out:
# <Axes: xlabel='DIM_TIME', ylabel='AMOUNT_N'>

# %% [markdown]
# **Insight**
#
# Life expectancy increases over time for all genders. Female life expectancy remains consistently higher.

# %% [markdown]
# Question. 13
#
# How are life expectancy categories distributed across genders?

# %%
sns.countplot(
    x='LIFE_EXPECTANCY_CATEGORY',
    hue='DIM_SEX',
    data=df
)
# Out:
# <Axes: xlabel='LIFE_EXPECTANCY_CATEGORY', ylabel='count'>

# %% [markdown]
# **Insight**
#
# High life expectancy categories are more common among females. Gender influences life expectancy outcomes.

# %% [markdown]
# Question. 14
#
# What correlations exist among numerical variables?

# %%
# Select numerical columns
corr_matrix = df[['AMOUNT_N',
                  'AMOUNT_NL',
                  'AMOUNT_NU',
                  'AMOUNT_N_Normalized']].corr()

# Plot heatmap
plt.figure(figsize=(8,6))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap of Numerical Variables')

plt.show()

# %% [markdown]
# **Insight**
#
# Strong positive correlations are observed among AMOUNT_N, AMOUNT_NL, AMOUNT_NU, and AMOUNT_N_Normalized.
#
# AMOUNT_NL (lower confidence limit) and AMOUNT_NU (upper confidence limit) are highly correlated with AMOUNT_N because they are derived from the same life expectancy estimate.
#
# AMOUNT_N_Normalized shows a perfect positive correlation (close to 1.00) with AMOUNT_N because it is a scaled version of the same variable.
# This indicates that as life expectancy increases, the corresponding confidence interval values also increase.

# %% [markdown]
# Question. 15
#
# How does normalized life expectancy vary across genders?

# %%
sns.scatterplot(
    x='AMOUNT_N',
    y='AMOUNT_N_Normalized',
    hue='DIM_SEX',
    data=df
)
# Out:
# <Axes: xlabel='AMOUNT_N', ylabel='AMOUNT_N_Normalized'>

# %% [markdown]
# **Insight**
#
# A strong positive relationship exists across all genders. Normalization preserves the original pattern of life expectancy values while standardizing the scale.

# %% [markdown]
# Question. 16
#
# How is life expectancy distributed across genders and life expectancy categories?

# %%
import plotly.express as px

fig = px.sunburst(
    df,
    path=['DIM_SEX', 'LIFE_EXPECTANCY_CATEGORY'],
    title='Life Expectancy Categories by Gender'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="904c9e53-9fc3-4bb9-9bbe-9f7be22deb4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("904c9e53-9fc3-4bb9-9bbe-9f7be22deb4d")) {                    Plotly.newPlot(                        "904c9e53-9fc3-4bb9-9bbe-9f7be22deb4d",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["FEMALE\u002fHigh","MALE\u002fHigh","TOTAL\u002fHigh","FEMALE\u002fLow","MALE\u002fLow","TOTAL\u002fLow","FEMALE\u002fMedium","MALE\u002fMedium","TOTAL\u002fMedium","FEMALE","MALE","TOTAL"],"labels":["High","High","High","Low","Low","Low","Medium","Medium","Medium","FEMALE","MALE","TOTAL"],"name":"","parents":["FEMALE","MALE","TOTAL","FEMALE","MALE","TOTAL","FEMALE","MALE","TOTAL","","",""],"values":[2211,904,1408,470,809,606,1631,2599,2298,4312,4312,4312],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolarg ...

# %% [markdown]
# **Insight**
#
# Shows the hierarchical distribution of life expectancy categories within each gender.Helps identify which life expectancy category is most common for each gender group.

# %% [markdown]
# Question. 17
#
# Which countries contribute most to high life expectancy values?

# %%
country_avg = df.groupby('GEO_NAME_SHORT')['AMOUNT_N'].mean().reset_index()

fig = px.treemap(
    country_avg,
    path=['GEO_NAME_SHORT'],
    values='AMOUNT_N',
    title='Average Life Expectancy by Country'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93926ffb-a167-4e9f-a177-4b8b8717ea47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93926ffb-a167-4e9f-a177-4b8b8717ea47")) {                    Plotly.newPlot(                        "93926ffb-a167-4e9f-a177-4b8b8717ea47",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eAMOUNT_N=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Afghanistan","Africa","Albania","Algeria","Americas","Angola","Antigua And Barbuda","Argentina","Armenia","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bhutan","Bolivia (Plurinational State Of)","Bosnia And Herzegovina","Botswana","Brazil","Brunei Darussalam","Bulgaria","Burkina Faso","Burundi","Cabo Verde","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo","Costa Rica","Croatia","Cuba","Cyprus","Czechia","Côte D'Ivoire","Democratic People'S Republic Of Korea","Democratic Republic Of The Congo","Denmark","Djibouti","Dominican Republic","Eastern Mediterranean","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Estonia","Eswatini","Ethiopia","Europe","Fiji","Finland","France","Gabon","Gambia","Georgia","Germany","Ghana","Greece","Grenada","Guatemala","Guinea","Guinea-Bissau","Guyana","Haiti","High-Income Economies","Honduras","Hungary","Iceland","India","Indonesia","Iran (Islamic Republic Of)","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kazakhstan","Kenya","Kiribati","Kuwait","Kyrgyzstan","Lao People'S Democratic Republic","Latvia","Lebanon","Lesotho","Liberia","Libya","Lithuania","Low-Income Economies","Lower-Middle-Income Economies","Luxembourg","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Mauritania","Mauritius","Mexico","Micronesia (Federated States Of)","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands (Kingdom Of The)","New Zealand","Nicaragua","Niger","Nigeria","North Macedonia","Norway","Occupied Palestinian Territory, Including East Jerusalem","Oman","Pakistan","Panama","Papua New Guinea","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Qatar","Republic Of Korea","Republic Of Moldova","Romania","Russian Federation","Rwanda","Saint Lucia","Saint Vincent And The Grenadines","Samoa","Sao Tome And Principe","Saudi Arabia","Senegal","Serbia","Seychelles","Sierra Leone","Singapore","Slovakia","Slovenia","Solomon Islands","Somalia","South Africa","South Sudan","South-East Asia","Spain","Sri Lanka","Sudan","Suriname","Sweden","Switzerland","Syrian Arab Republic","Tajikistan","Thailand","Timor-Leste","Togo","Tonga","Trinidad And Tobago","Tunisia","Turkmenistan","Türkiye","Uganda","Ukraine","United Arab Emirates","United Kingdom Of Great Britain And Northern Ireland","United Republic Of Tanzania","United States Of America","Upper-Middle-Income Economies","Uruguay","Uzbekistan","Vanuatu","Venezuela (Bolivarian Republic Of)","Viet Nam","Western Pacific","World","Yemen","Zambia","Zimbabwe"],"labels":["Afghanistan","Africa","Albania","Algeria","Americas","Angola","Antigua And Barbuda","Argentina","Armenia","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bhutan","Bolivia (Plurinational State Of)","Bosnia And Herzegovina","Botswana","Brazil","Brunei Darussalam","Bulgaria","Burkina Faso","Burundi","Cabo Verde","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo","Costa Rica","Croatia","Cuba","Cyprus","Czechia" ...

# %% [markdown]
# **Insight**
#
# Each rectangle represents a country. Larger rectangles indicate countries with higher average life expectancy.

# %% [markdown]
# Question. 18
#
# How has life expectancy changed over time by gender?

# %%
gender_year = df.groupby(
    ['DIM_TIME','DIM_SEX']
)['AMOUNT_N'].mean().reset_index()

fig = px.line(
    gender_year,
    x='DIM_TIME',
    y='AMOUNT_N',
    color='DIM_SEX',
    markers=True,
    title='Life Expectancy Trend by Gender'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a3d1374-99bc-4412-ad39-f63fff7e6f96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a3d1374-99bc-4412-ad39-f63fff7e6f96")) {                    Plotly.newPlot(                        "5a3d1374-99bc-4412-ad39-f63fff7e6f96",                        [{"hovertemplate":"DIM_SEX=FEMALE\u003cbr\u003eDIM_TIME=%{x}\u003cbr\u003eAMOUNT_N=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FEMALE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"FEMALE","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[69.43713087183673,69.73217184459183,69.94181850872448,70.19354682877551,70.51669260816327,70.91030801188776,71.3638307694898,71.76034495801021,72.1073890964796,72.4987373732653,72.71019183867347,73.14598578193878,73.48025459173469,73.79384620209183,73.97941901719388,74.15834726051021,74.42812006341836,74.64316120479592,74.8900282067347,75.05421436107143,74.71064451336734,73.75124929387755],"yaxis":"y","type":"scatter"},{"hovertemplate":"DIM_SEX=MALE\u003cbr\u003eDIM_TIME=%{x}\u003cbr\u003eAMOUNT_N=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MALE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"MALE","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[64.5556160912245,64.9137981489796,65.17020788698979,65.46695120693877,65.81463972571429,66.1400952607653,66.57589133387755,66.91851801061225,67.2466305229592,67.64603566173469,67.9672486917347,68.34861693392857,68.64844600841836,68.96309174086736,69.10348697836736,69.29882705392858,69.5535626507653,69.7853561067347,70.02294123086735,70.26266193367347,69.51484165372449,68.90438888765306],"yaxis":"y","type":"scatter"},{"hovertemplate":"DIM_SEX=TOTAL\u003cbr\u003eDIM_TIME=%{x}\u003cbr\u003eAMOUNT_N=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TOTAL","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"TOTAL","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[66.95347901387755,67.28225930102042,67.51460510831632,67.7897017069898,68.12584626408163,68.48122248045918,68.9287454072449,69.29977593637754,69.63990375010204,70.03901858367347,70.30799313413266,70.72171522168367,71.039066785,71.35420233882652,71.51334416056123,71.69916095571429,71.96081183382653,72.18507047091836,72.43173033188775,72.63534242005102,72.05955757632653,71.28690038535714],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"hea ...

# %% [markdown]
# **Insight**
#
# Shows life expectancy trends for Male, Female, and Both categories. Female life expectancy consistently remains higher across years.

# %% [markdown]
# **📋 Pivot Table Analysis**

# %% [markdown]
# Question. 19
#
# How does average life expectancy vary across years and genders?

# %%
pivot_heatmap = pd.pivot_table(
    df,
    values='AMOUNT_N',
    index='DIM_TIME',
    columns='DIM_SEX',
    aggfunc='mean'
)

plt.figure(figsize=(10,6))

sns.heatmap(
    pivot_heatmap,
    annot=True,
    fmt='.1f',
    cmap='YlGnBu'
)

plt.title('Average Life Expectancy by Year and Gender')

plt.show()

# %% [markdown]
# **Insight**
#
# Displays average life expectancy for each gender across years. Makes it easy to identify trends and compare gender differences over time.

# %% [markdown]
# Question. 20
#
# Which year had the highest life expectancy?

# %%
pivot_year_max = pd.pivot_table(
    df,
    values='AMOUNT_N',
    index='DIM_TIME',
    aggfunc='mean'
).sort_values(by='AMOUNT_N', ascending=False)

print(pivot_year_max.head())
# Out:
#            AMOUNT_N
# DIM_TIME
# 2019      72.650740
# 2018      72.448233
# 2017      72.204529
# 2020      72.095015
# 2016      71.980832

# %% [markdown]
# **Insight**
#
# Lists years with the highest average life expectancy. Identifies periods of peak global health outcomes.

# %% [markdown]
# Question. 21
#
# Which gender shows greater variation in life expectancy?

# %%
pivot_std = pd.pivot_table(
    df,
    values='AMOUNT_N',
    index='DIM_SEX',
    aggfunc='std'
)

print(pivot_std)
# Out:
#          AMOUNT_N
# DIM_SEX
# FEMALE   8.879291
# MALE     8.306886
# TOTAL    8.530997

# %% [markdown]
# **Insight**
#
# Shows standard deviation for each gender. Higher standard deviation indicates greater variation in life expectancy values.

# %% [markdown]
# Question. 22
#
# What is the average life expectancy by country and gender?

# %%
pivot_multi = pd.pivot_table(
    df,
    values='AMOUNT_N',
    index=['GEO_NAME_SHORT', 'DIM_SEX'],
    aggfunc='mean'
)

print(pivot_multi.head(20))
# Out:
#                               AMOUNT_N
# GEO_NAME_SHORT      DIM_SEX
# Afghanistan         FEMALE   59.179078
#                     MALE     57.732007
#                     TOTAL    58.417441
# Africa              FEMALE   60.916106
#                     MALE     57.643637
#                     TOTAL    59.282039
# Albania             FEMALE   78.665428
#                     MALE     74.036680
#                     TOTAL    76.246067
# Algeria             FEMALE   75.683266
#                     MALE     74.296670
#                     TOTAL    74.914253
# Americas            FEMALE   78.578683
#                     MALE     73.031260
#                     TOTAL    75.797223
# Angola              FEMALE   59.607283
#                     MALE     55.267059
#                     TOTAL    57.427750
# Antigua And Barbuda FEMALE   77.511562
#                     MALE     73.367989

# %% [markdown]
# **Insight**
#
# Displays average life expectancy for each country-gender combination. Provides detailed country-level demographic analysis.

# %% [markdown]
# # 💡 **Key Insights**

# %% [markdown]
# 💡**1: Female Life Expectancy is Higher**
#
# Observation
#
# The average life expectancy of females is consistently higher than that of males.
#
# Insight
#
# This suggests that women generally have greater longevity across most countries.

# %% [markdown]
# 💡**2: Global Life Expectancy Shows an Upward Trend**
#
# Observation
#
# The line chart of average life expectancy over time shows a gradual increase.
#
# Insight
#
# Improvements in healthcare, sanitation, nutrition, and living standards have contributed to longer lifespans.

# %% [markdown]
# 💡**3: Significant Differences Exist Between Countries**
#
# Observation
#
# The Top 10 and Bottom 10 country analyses reveal large variations in life expectancy.
#
# Insight
#
# Socio-economic conditions, healthcare infrastructure, and public health policies strongly influence life expectancy.

# %% [markdown]
# 💡**4: Most Countries Fall into Medium and High Categories**
#
# Observation
#
# The count plot of LIFE_EXPECTANCY_CATEGORY shows that most records belong to Medium and High groups.
#
# Insight
#
# Many countries have achieved considerable improvements in population health and longevity.

# %% [markdown]
# 💡**5: Strong Correlation Exists Between Life Expectancy and Confidence Limits**
#
# Observation
#
# The correlation heatmap shows high positive correlations among AMOUNT_N, AMOUNT_NL, and AMOUNT_NU.
#
# Insight
#
# Countries with higher life expectancy also tend to have higher lower and upper confidence interval estimates.

# %% [markdown]
# 💡**6: Presence of Outliers Indicates Global Health Inequality**
#
# Observation
#
# The boxplot and IQR method identified several outliers.
#
# Insight
#
# These outliers represent countries with exceptionally low life expectancy and highlight disparities in global health outcomes.

# %% [markdown]
# 💡**7: Normalization Preserved Data Patterns**
#
# Observation
#
# The normalized life expectancy values maintain the same ranking as the original values.
#
# Insight
#
# Data transformation standardized the scale without altering the underlying relationships.

# %% [markdown]
# # **📋 Summary**

# %% [markdown]
# This project analyzed global life expectancy data using Python. The dataset was cleaned by handling missing values, checking duplicates, standardizing text formats, and creating derived features. Data transformation and outlier detection were performed to improve data quality.
#
# Exploratory Data Analysis (EDA) was conducted using univariate, bivariate, and multivariate techniques. Various visualizations helped identify trends, patterns, and relationships within the data.
#
# The analysis revealed gender-based differences, country-level variations, positive life expectancy trends over time, and significant correlations among numerical variables.

# %% [markdown]
# # **✅ Conclusion**

# %% [markdown]
# The objective of this project was to analyze global life expectancy data and identify factors influencing lifespan across different populations.
#
# The results showed that:
#
# -Female life expectancy is generally higher than male life expectancy.
#
# -Global life expectancy has improved over time.
#
# -Significant differences exist among countries.
#
# -Most observations belong to medium and high life expectancy categories.
#
# -Strong correlations exist among life expectancy measures.
#
#
# Through data cleaning, preprocessing, exploratory analysis, and visualization, this project successfully identified important trends and disparities in global life expectancy, demonstrating the value of data analytics in understanding public health outcomes.
